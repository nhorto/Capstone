# %%
from preprocessing import SolarDataProcessor
from LSTM import LSTMForecastModel
from XGBoost import XGBoostModel
from Blender import Blender

# %%
processor = SolarDataProcessor()
df = processor.process_data('Inv_2024-09-30.csv', 'weather_2024-09-30.csv')
# Out:
# Resampled to 10min with tolerance 5min
# Resulting rows: 8784
# All missing values successfully filled.

# %%
blender = Blender(df)
blender.run_models(lstm_freq='15min', xgb_freq='60min', lstm_horizon=18, xgb_horizon=18)
# Out:
# /Users/nicholashorton/Documents/Capstone/test/LSTM.py:169: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_resampled[feature_name] = df_resampled[col].diff(periods=periods)
# /Users/nicholashorton/Documents/Capstone/test/LSTM.py:169: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_resampled[feature_name] = df_resampled[col].diff(periods=periods)
# /Users/nicholashorton/Documents/Capstone/test/LSTM.py:169: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_resampled[feature_name] = df_resampled[col].diff(periods=periods)
# /Users/nicholashorton/Documents/Capstone/test/LSTM.py:175: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df_clean[self.features] = self.scaler.fit_transform(self.df_clean[self.features])
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Warning: total_output_power_kW not found in dataframe, skipping
# Epoch 1/50
# 116/116 [==============================] - 2s 5ms/step - loss: 1138831.6250 - mae: 655.9818 - val_loss: 1527488.3750 - val_mae: 905.9395
# Epoch 2/50
# 116/116 [==============================] - 0s 3ms/step - loss: 844962.1250 - mae: 736.4555 - val_loss: 1155088.5000 - val_mae: 673.0681
# Epoch 3/50
# 116/116 [==============================] - 0s 4ms/step - loss: 503620.7812 - mae: 421.4199 - val_loss: 585003.5625 - val_mae: 478.6233
# Epoch 4/50
# 116/116 [==============================] - 0s 3ms/step - loss: 302699.3750 - mae: 319.5861 - val_loss: 403696.7188 - val_mae: 387.7507
# Epoch 5/50
# 116/116 [==============================] - 0s 4ms/step - loss: 253421.6094 - mae: 291.4290 - val_loss: 404718.8125 - val_mae: 384.4126
# Epoch 6/50
# 116/116 [==============================] - 0s 4ms/step - loss: 252666.0938 - mae: 288.6189 - val_loss: 481547.7500 - val_mae: 416.5145
# Epoch 7/50
# 116/116 [==============================] - 0s 4ms/step - loss: 242063.7812 - mae: 286.0889 - val_loss: 457977.8438 - val_mae: 407.8262
# Epoch 8/50
# 116/116 [==============================] - 0s 4ms/step - loss: 249799.7031 - mae: 287.2284 - val_loss: 544343.0625 - val_mae: 437.5115
# Epoch 9/50
# 116/116 [==============================] - 0s 4ms/step - loss: 243179.5312 - mae: 284.0434 - val_loss: 413087.8125 - val_mae: 392.4370
# Epoch 10/50
# 116/116 [==============================] - 0s 4ms/step - loss: 236416.3281 - mae: 279.7131 - val_loss: 431055.0312 - val_mae: 395.0807
# Epoch 11/50
# 116/116 [==============================] - 0s 4ms/step - loss: 224954.4219 - mae: 272.5258 - val_loss: 557177.0000 - val_mae: 443.2166
# Epoch 12/50
# 116/116 [==============================] - 0s 3ms/step - loss: 222946.9219 - mae: 268.3851 - val_loss: 628193.3750 - val_mae: 466.3484
# Epoch 13/50
# 116/116 [==============================] - 0s 4ms/step - loss: 229128.6562 - mae: 272.5624 - val_loss: 503198.9688 - val_mae: 423.3093
# Epoch 14/50
# 116/116 [==============================] - 0s 4ms/step - loss: 222192.2188 - mae: 268.5383 - val_loss: 473573.5312 - val_mae: 411.0999
# 15/15 [==============================] - 0s 1ms/step
# Warning: total_output_power_kW not found in dataframe, skipping
# 8/8 [==============================] - 0s 2ms/step
# Warning: total_output_power_kW not found in dataframe, skipping
# 8/8 [==============================] - 0s 2ms/step
# Warning: total_output_power_kW not found in dataframe, skipping
# Added direct feature: WMS 01 irradiance
# Added direct feature: average_temperature_C
# Added direct feature: total_last_active_fault
# Added direct feature: total_net_AC_voltage_V
# Added direct feature: total_time_run_today_h
# Added direct feature: average_average_cosphii_percent
# Added direct feature: total_DC_voltage_DCV
# Added direct feature: total_output_current_A
# Added direct feature: total_grid_connections
# Added direct feature: total_net_frequency_Hz
# Total features created: 123
# THES ARE THE COLUMNS: ['total_Accumulated Export Energy', 'total_energy_counter_MWh', 'total_time_run_today_h', 'total_time_run_yesterday_h', 'total_grid_connections', 'total_time_run_total_h', 'average_average_cosphii_percent', 'total_DC_voltage_DCV', 'total_Export Energy', 'total_net_AC_voltage_V', 'total_todays_energy_kWh', 'total_last_active_fault', 'total_output_current_A', 'average_temperature_C', 'total_yesterdays_energy_kWh', 'total_net_frequency_Hz', 'WMS 01 ambient_temperature', 'WMS 01 irradiance', 'WMS 01 wind_speed', 'hour', 'day', 'month', 'dayofweek', 'quarter', 'minute', 'hours_since_sunrise', 'hours_until_sunset', 'is_daytime', 'peak_sun_factor', 'hour_sin', 'hour_cos', 'month_sin', 'month_cos', 'irradiance_future', 'power_future', 'average_temperature_C_lag_1', 'average_temperature_C_lag_3', 'average_temperature_C_lag_6', 'average_temperature_C_lag_12', 'average_temperature_C_mean_1', 'average_temperature_C_mean_2', 'average_temperature_C_mean_3', 'average_temperature_C_mean_6', 'average_temperature_C_mean_12', 'average_temperature_C_mean_24', 'average_temperature_C_std_2', 'average_temperature_C_std_3', 'average_temperature_C_std_6', 'average_temperature_C_diff_1', 'average_temperature_C_diff_2', 'average_temperature_C_diff_3', 'total_DC_voltage_DCV_lag_1', 'total_DC_voltage_DCV_lag_3', 'total_DC_voltage_DCV_lag_6', 'total_DC_voltage_DCV_mean_1', 'total_DC_voltage_DCV_mean_2', 'total_DC_voltage_DCV_mean_3', 'total_DC_voltage_DCV_mean_6', 'total_DC_voltage_DCV_mean_12', 'total_DC_voltage_DCV_mean_24', 'total_DC_voltage_DCV_std_2', 'total_DC_voltage_DCV_std_3', 'total_DC_voltage_DCV_std_6', 'total_DC_voltage_DCV_diff_1', 'total_DC_voltage_DCV_diff_2', 'total_DC_voltage_DCV_diff_3', 'total_output_current_A_lag_1', 'total_output_current_A_lag_3', 'total_output_current_A_lag_6', 'total_output_current_A_mean_1', 'total_output_current_A_mean_2', 'total_output_current_A_mean_3', 'total_output_current_A_mean_6', 'total_output_current_A_mean_12', 'total_output_current_A_mean_24', 'total_output_current_A_std_2', 'total_output_current_A_std_3', 'total_output_current_A_std_6', 'total_output_current_A_diff_1', 'total_output_current_A_diff_2', 'total_output_current_A_diff_3', 'average_average_cosphii_percent_lag_1', 'average_average_cosphii_percent_lag_3', 'average_average_cosphii_percent_lag_6', 'average_average_cosphii_percent_mean_1', 'average_average_cosphii_percent_mean_2', 'average_average_cosphii_percent_mean_3', 'average_average_cosphii_percent_mean_6', 'average_average_cosphii_percent_mean_12', 'average_average_cosphii_percent_mean_24', 'average_average_cosphii_percent_diff_1', 'average_average_cosphii_percent_diff_2', 'average_average_cosphii_percent_diff_3', 'total_time_run_today_h_lag_1', 'total_time_run_today_h_lag_3', 'total_time_run_today_h_lag_6', 'total_time_run_today_h_sum_1', 'total_time_run_today_h_sum_3', 'total_time_run_today_h_sum_6', 'total_time_run_today_h_sum_12', 'total_time_run_today_h_sum_24', 'total_time_run_today_h_diff_1', 'total_time_run_today_h_diff_2', 'total_time_run_today_h_diff_3', 'total_last_active_fault_lag_1', 'total_last_active_fault_lag_3', 'total_last_active_fault_sum_1', 'total_last_active_fault_sum_3', 'total_last_active_fault_sum_6', 'total_last_active_fault_sum_12', 'total_last_active_fault_sum_24', 'total_last_active_fault_diff_1', 'total_last_active_fault_diff_2', 'total_last_active_fault_diff_3', 'WMS 01 irradiance_lag_0', 'WMS 01 irradiance_lag_1', 'WMS 01 irradiance_lag_2', 'WMS 01 irradiance_lag_3', 'WMS 01 irradiance_lag_6', 'WMS 01 irradiance_lag_12', 'WMS 01 irradiance_lag_24', 'WMS 01 irradiance_mean_1', 'WMS 01 irradiance_mean_3', 'WMS 01 irradiance_mean_6', 'WMS 01 irradiance_mean_12', 'WMS 01 irradiance_std_2', 'WMS 01 irradiance_std_3', 'WMS 01 irradiance_std_6', 'WMS 01 irradiance_max_1', 'WMS 01 irradiance_max_2', 'WMS 01 irradiance_max_3', 'WMS 01 irradiance_max_6', 'WMS 01 irradiance_diff_1', 'WMS 01 irradiance_diff_2', 'WMS 01 irradiance_diff_3', 'WMS 01 i ...
# /Users/nicholashorton/Documents/Capstone/test/LSTM.py:358: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_resampled[feature_name] = df_resampled[col].diff(periods=periods)
# /Users/nicholashorton/Documents/Capstone/test/LSTM.py:358: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_resampled[feature_name] = df_resampled[col].diff(periods=periods)
# /Users/nicholashorton/Documents/Capstone/test/LSTM.py:358: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_resampled[feature_name] = df_resampled[col].diff(periods=periods)
# /Users/nicholashorton/Documents/Capstone/test/LSTM.py:358: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_resampled[feature_name] = df_resampled[col].diff(periods=periods)
# /Users/nicholashorton/Documents/Capstone/test/LSTM.py:358: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_resampled[feature_name] = df_resampled[col].diff(periods=periods)
# /Users/nicholashorton/Documents/Capstone/test/LSTM.py:358: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_resampled[feature_name] = df_resampled[col].diff(periods=periods)
# /Users/nicholashorton/Documents/Capstone/test/XGBoost.py:185: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_resampled[feature_name] = df_resampled[col].diff(periods=periods)
# /Users/nicholashorton/Documents/Capstone/test/XGBoost.py:185: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_resampled[feature_name] = df_resampled[col].diff(periods=periods)
# /Users/nicholashorton/Documents/Capstone/test/XGBoost.py:185: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_resampled[feature_name] = df_resampled[col].diff(periods=periods)
# /Users/nicholashorton/Documents/Capstone/test/XGBoost.py:185: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_resampled[feature_name] = df_resampled[col].diff(periods=periods)
# /Users/nicholashorton/Documents/Capstone/test/XGBoost.py:185: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_resampled[feature_name] = df_resampled[col].diff(periods=periods)
# /Users/nicholashorton/Documents/Capstone/test/XGBoost.py:198: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_resampled['irr_temp_interaction'] = df_resampled['WMS 01 irradiance'] * df_resampled['average_temperature_C']
# /Users/nicholashorton/Documents/Capstone/test/XGBoost.py:199: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_resampled['irr_time_interaction'] = df_resampled['WMS 01 irradiance'] * df_resampled['peak_sun_factor']
# Training Metrics:
# RMSE: 329.6797
# MAE: 194.6568
# R2: 0.8725
#
# Test Metrics:
# RMSE: 481.5559
# MAE: 314.8191
# R2: 0.8188
# NRMSE: 0.5272
# NMAE: 0.3447
# Warning: total_output_power_kW not found in dataframe, skipping
# Added direct feature: WMS 01 irradiance
# Added direct feature: average_temperature_C
# Added direct feature: total_last_active_fault
# Added direct feature: total_net_AC_voltage_V
# Added direct feature: total_time_run_today_h
# Added direct feature: average_average_cosphii_percent
# Added direct feature: total_DC_voltage_DCV
# Added direct feature: total_output_current_A
# Added direct feature: total_grid_connections
# Added direct feature: total_net_frequency_Hz
# Total features created: 123
# THES ARE THE COLUMNS: ['total_Accumulated Export Energy', 'total_energy_counter_MWh', 'total_time_run_today_h', 'total_time_run_yesterday_h', 'total_grid_connections', 'total_time_run_total_h', 'average_average_cosphii_percent', 'total_DC_voltage_DCV', 'total_Export Energy', 'total_net_AC_voltage_V', 'total_todays_energy_kWh', 'total_last_active_fault', 'total_output_current_A', 'average_temperature_C', 'total_yesterdays_energy_kWh', 'total_net_frequency_Hz', 'WMS 01 ambient_temperature', 'WMS 01 irradiance', 'WMS 01 wind_speed', 'hour', 'day', 'month', 'dayofweek', 'quarter', 'minute', 'hours_since_sunrise', 'hours_until_sunset', 'is_daytime', 'peak_sun_factor', 'hour_sin', 'hour_cos', 'month_sin', 'month_cos', 'irradiance_future', 'power_future', 'average_temperature_C_lag_1', 'average_temperature_C_lag_3', 'average_temperature_C_lag_6', 'average_temperature_C_lag_12', 'average_temperature_C_mean_1', 'average_temperature_C_mean_2', 'average_temperature_C_mean_3', 'average_temperature_C_mean_6', 'average_temperature_C_mean_12', 'average_temperature_C_mean_24', 'average_temperature_C_std_2', 'average_temperature_C_std_3', 'average_temperature_C_std_6', 'average_temperature_C_diff_1', 'average_temperature_C_diff_2', 'average_temperature_C_diff_3', 'total_DC_voltage_DCV_lag_1', 'total_DC_voltage_DCV_lag_3', 'total_DC_voltage_DCV_lag_6', 'total_DC_voltage_DCV_mean_1', 'total_DC_voltage_DCV_mean_2', 'total_DC_voltage_DCV_mean_3', 'total_DC_voltage_DCV_mean_6', 'total_DC_voltage_DCV_mean_12', 'total_DC_voltage_DCV_mean_24', 'total_DC_voltage_DCV_std_2', 'total_DC_voltage_DCV_std_3', 'total_DC_voltage_DCV_std_6', 'total_DC_voltage_DCV_diff_1', 'total_DC_voltage_DCV_diff_2', 'total_DC_voltage_DCV_diff_3', 'total_output_current_A_lag_1', 'total_output_current_A_lag_3', 'total_output_current_A_lag_6', 'total_output_current_A_mean_1', 'total_output_current_A_mean_2', 'total_output_current_A_mean_3', 'total_output_current_A_mean_6', 'total_output_current_A_mean_12', 'total_output_current_A_mean_24', 'total_output_current_A_std_2', 'total_output_current_A_std_3', 'total_output_current_A_std_6', 'total_output_current_A_diff_1', 'total_output_current_A_diff_2', 'total_output_current_A_diff_3', 'average_average_cosphii_percent_lag_1', 'average_average_cosphii_percent_lag_3', 'average_average_cosphii_percent_lag_6', 'average_average_cosphii_percent_mean_1', 'average_average_cosphii_percent_mean_2', 'average_average_cosphii_percent_mean_3', 'average_average_cosphii_percent_mean_6', 'average_average_cosphii_percent_mean_12', 'average_average_cosphii_percent_mean_24', 'average_average_cosphii_percent_diff_1', 'average_average_cosphii_percent_diff_2', 'average_average_cosphii_percent_diff_3', 'total_time_run_today_h_lag_1', 'total_time_run_today_h_lag_3', 'total_time_run_today_h_lag_6', 'total_time_run_today_h_sum_1', 'total_time_run_today_h_sum_3', 'total_time_run_today_h_sum_6', 'total_time_run_today_h_sum_12', 'total_time_run_today_h_sum_24', 'total_time_run_today_h_diff_1', 'total_time_run_today_h_diff_2', 'total_time_run_today_h_diff_3', 'total_last_active_fault_lag_1', 'total_last_active_fault_lag_3', 'total_last_active_fault_sum_1', 'total_last_active_fault_sum_3', 'total_last_active_fault_sum_6', 'total_last_active_fault_sum_12', 'total_last_active_fault_sum_24', 'total_last_active_fault_diff_1', 'total_last_active_fault_diff_2', 'total_last_active_fault_diff_3', 'WMS 01 irradiance_lag_0', 'WMS 01 irradiance_lag_1', 'WMS 01 irradiance_lag_2', 'WMS 01 irradiance_lag_3', 'WMS 01 irradiance_lag_6', 'WMS 01 irradiance_lag_12', 'WMS 01 irradiance_lag_24', 'WMS 01 irradiance_mean_1', 'WMS 01 irradiance_mean_3', 'WMS 01 irradiance_mean_6', 'WMS 01 irradiance_mean_12', 'WMS 01 irradiance_std_2', 'WMS 01 irradiance_std_3', 'WMS 01 irradiance_std_6', 'WMS 01 irradiance_max_1', 'WMS 01 irradiance_max_2', 'WMS 01 irradiance_max_3', 'WMS 01 irradiance_max_6', 'WMS 01 irradiance_diff_1', 'WMS 01 irradiance_diff_2', 'WMS 01 irradiance_diff_3', 'WMS 01 i ...
# Warning: total_output_power_kW not found in dataframe, skipping
# Added direct feature: WMS 01 irradiance
# Added direct feature: average_temperature_C
# Added direct feature: total_last_active_fault
# Added direct feature: total_net_AC_voltage_V
# Added direct feature: total_time_run_today_h
# Added direct feature: average_average_cosphii_percent
# Added direct feature: total_DC_voltage_DCV
# Added direct feature: total_output_current_A
# Added direct feature: total_grid_connections
# Added direct feature: total_net_frequency_Hz
# Total features created: 123
# THES ARE THE COLUMNS: ['total_Accumulated Export Energy', 'total_energy_counter_MWh', 'total_time_run_today_h', 'total_time_run_yesterday_h', 'total_grid_connections', 'total_time_run_total_h', 'average_average_cosphii_percent', 'total_DC_voltage_DCV', 'total_Export Energy', 'total_net_AC_voltage_V', 'total_todays_energy_kWh', 'total_last_active_fault', 'total_output_current_A', 'average_temperature_C', 'total_yesterdays_energy_kWh', 'total_net_frequency_Hz', 'WMS 01 ambient_temperature', 'WMS 01 irradiance', 'WMS 01 wind_speed', 'hour', 'day', 'month', 'dayofweek', 'quarter', 'minute', 'hours_since_sunrise', 'hours_until_sunset', 'is_daytime', 'peak_sun_factor', 'hour_sin', 'hour_cos', 'month_sin', 'month_cos', 'irradiance_future', 'power_future', 'average_temperature_C_lag_1', 'average_temperature_C_lag_3', 'average_temperature_C_lag_6', 'average_temperature_C_lag_12', 'average_temperature_C_mean_1', 'average_temperature_C_mean_2', 'average_temperature_C_mean_3', 'average_temperature_C_mean_6', 'average_temperature_C_mean_12', 'average_temperature_C_mean_24', 'average_temperature_C_std_2', 'average_temperature_C_std_3', 'average_temperature_C_std_6', 'average_temperature_C_diff_1', 'average_temperature_C_diff_2', 'average_temperature_C_diff_3', 'total_DC_voltage_DCV_lag_1', 'total_DC_voltage_DCV_lag_3', 'total_DC_voltage_DCV_lag_6', 'total_DC_voltage_DCV_mean_1', 'total_DC_voltage_DCV_mean_2', 'total_DC_voltage_DCV_mean_3', 'total_DC_voltage_DCV_mean_6', 'total_DC_voltage_DCV_mean_12', 'total_DC_voltage_DCV_mean_24', 'total_DC_voltage_DCV_std_2', 'total_DC_voltage_DCV_std_3', 'total_DC_voltage_DCV_std_6', 'total_DC_voltage_DCV_diff_1', 'total_DC_voltage_DCV_diff_2', 'total_DC_voltage_DCV_diff_3', 'total_output_current_A_lag_1', 'total_output_current_A_lag_3', 'total_output_current_A_lag_6', 'total_output_current_A_mean_1', 'total_output_current_A_mean_2', 'total_output_current_A_mean_3', 'total_output_current_A_mean_6', 'total_output_current_A_mean_12', 'total_output_current_A_mean_24', 'total_output_current_A_std_2', 'total_output_current_A_std_3', 'total_output_current_A_std_6', 'total_output_current_A_diff_1', 'total_output_current_A_diff_2', 'total_output_current_A_diff_3', 'average_average_cosphii_percent_lag_1', 'average_average_cosphii_percent_lag_3', 'average_average_cosphii_percent_lag_6', 'average_average_cosphii_percent_mean_1', 'average_average_cosphii_percent_mean_2', 'average_average_cosphii_percent_mean_3', 'average_average_cosphii_percent_mean_6', 'average_average_cosphii_percent_mean_12', 'average_average_cosphii_percent_mean_24', 'average_average_cosphii_percent_diff_1', 'average_average_cosphii_percent_diff_2', 'average_average_cosphii_percent_diff_3', 'total_time_run_today_h_lag_1', 'total_time_run_today_h_lag_3', 'total_time_run_today_h_lag_6', 'total_time_run_today_h_sum_1', 'total_time_run_today_h_sum_3', 'total_time_run_today_h_sum_6', 'total_time_run_today_h_sum_12', 'total_time_run_today_h_sum_24', 'total_time_run_today_h_diff_1', 'total_time_run_today_h_diff_2', 'total_time_run_today_h_diff_3', 'total_last_active_fault_lag_1', 'total_last_active_fault_lag_3', 'total_last_active_fault_sum_1', 'total_last_active_fault_sum_3', 'total_last_active_fault_sum_6', 'total_last_active_fault_sum_12', 'total_last_active_fault_sum_24', 'total_last_active_fault_diff_1', 'total_last_active_fault_diff_2', 'total_last_active_fault_diff_3', 'WMS 01 irradiance_lag_0', 'WMS 01 irradiance_lag_1', 'WMS 01 irradiance_lag_2', 'WMS 01 irradiance_lag_3', 'WMS 01 irradiance_lag_6', 'WMS 01 irradiance_lag_12', 'WMS 01 irradiance_lag_24', 'WMS 01 irradiance_mean_1', 'WMS 01 irradiance_mean_3', 'WMS 01 irradiance_mean_6', 'WMS 01 irradiance_mean_12', 'WMS 01 irradiance_std_2', 'WMS 01 irradiance_std_3', 'WMS 01 irradiance_std_6', 'WMS 01 irradiance_max_1', 'WMS 01 irradiance_max_2', 'WMS 01 irradiance_max_3', 'WMS 01 irradiance_max_6', 'WMS 01 irradiance_diff_1', 'WMS 01 irradiance_diff_2', 'WMS 01 irradiance_diff_3', 'WMS 01 i ...
# /Users/nicholashorton/Documents/Capstone/test/XGBoost.py:185: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_resampled[feature_name] = df_resampled[col].diff(periods=periods)
# /Users/nicholashorton/Documents/Capstone/test/XGBoost.py:185: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_resampled[feature_name] = df_resampled[col].diff(periods=periods)
# /Users/nicholashorton/Documents/Capstone/test/XGBoost.py:185: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_resampled[feature_name] = df_resampled[col].diff(periods=periods)
# /Users/nicholashorton/Documents/Capstone/test/XGBoost.py:185: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_resampled[feature_name] = df_resampled[col].diff(periods=periods)
# /Users/nicholashorton/Documents/Capstone/test/XGBoost.py:185: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_resampled[feature_name] = df_resampled[col].diff(periods=periods)
# /Users/nicholashorton/Documents/Capstone/test/XGBoost.py:198: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_resampled['irr_temp_interaction'] = df_resampled['WMS 01 irradiance'] * df_resampled['average_temperature_C']
# /Users/nicholashorton/Documents/Capstone/test/XGBoost.py:199: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_resampled['irr_time_interaction'] = df_resampled['WMS 01 irradiance'] * df_resampled['peak_sun_factor']
# /Users/nicholashorton/Documents/Capstone/test/XGBoost.py:185: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_resampled[feature_name] = df_resampled[col].diff(periods=periods)
# /Users/nicholashorton/Documents/Capstone/test/XGBoost.py:185: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_resampled[feature_name] = df_resampled[col].diff(periods=periods)
# /Users/nicholashorton/Documents/Capstone/test/XGBoost.py:185: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_resampled[feature_name] = df_resampled[col].diff(periods=periods)
# /Users/nicholashorton/Documents/Capstone/test/XGBoost.py:185: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_resampled[feature_name] = df_resampled[col].diff(periods=periods)
# /Users/nicholashorton/Documents/Capstone/test/XGBoost.py:185: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_resampled[feature_name] = df_resampled[col].diff(periods=periods)
# /Users/nicholashorton/Documents/Capstone/test/XGBoost.py:198: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_resampled['irr_temp_interaction'] = df_resampled['WMS 01 irradiance'] * df_resampled['average_temperature_C']
# /Users/nicholashorton/Documents/Capstone/test/XGBoost.py:199: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_resampled['irr_time_interaction'] = df_resampled['WMS 01 irradiance'] * df_resampled['peak_sun_factor']
