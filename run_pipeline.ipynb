# %%
import sys
import os
sys.path.append(os.getcwd())  # Add current directory to Python path

# Then your imports
import pandas as pd
from preprocessing import SolarDataProcessor
from base_model import baseModel
from XGBoost import XGBoost
from LSTM import LSTMForecastModel
from blender import blender

# %%
# Import preprocessing and models
# from preprocessing import SolarDataProcessor
# from base_model import baseModel
# from XGBoost import XGBoost
# from LSTM import LSTMForecastModel
# from blender import blender

# ======================================
# Step 1: Preprocess your raw data
# ======================================
processor = SolarDataProcessor()
df = processor.process_data('Inv_2024-09-30.csv', 'weather_2024-09-30.csv')

# ===============================
# Run Base Model
# ===============================
# base_model = baseModel(data=df)

# base_model_results = base_model.run_pipeline()

# =====================================
# Run only XGBoost Model 
# =====================================
# XGBoost_model = XGBoost(data=df.reset_index())
# XGBoost_results = XGBoost_model.run_pipeline()

# ==================================
# Run only LSTM Model (commented out)
# ==================================
# lstm_model = LSTMForecastModel(data=df)
# results = lstm_model.run_pipeline()

# ===========================
# Run Blended + Residual Model
# ===========================
blender = blender(df)
blender.run_models(lstm_freq='15min', xgb_freq='60min', lstm_horizon=18, xgb_horizon=18)

blender.train_blended_model()
blender.train_residual_model()
blender.apply_residual_correction()
blender.evaluate_blend_model(blender.y_blend_true)
blender.plot_blend_diagnostics()
# Out:
# ...
# /Users/nicholashorton/Documents/Capstone/From Git/LSTM.py:169: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_resampled[feature_name] = df_resampled[col].diff(periods=periods)
# /Users/nicholashorton/Documents/Capstone/From Git/LSTM.py:169: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_resampled[feature_name] = df_resampled[col].diff(periods=periods)
# ...
